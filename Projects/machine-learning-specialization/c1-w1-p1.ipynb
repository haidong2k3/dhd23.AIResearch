# %% [markdown]
# ## c1 w1 p1

# %% [markdown]
# * Artificial Intelligent nói chung và Machine Learning nói riêng ngày nay được ứng dụng rộng rãi trong khắp mọi lĩnh vực, từ sản xuất nông nghiệp đến y học, kinh tế, giáo dục,,,,
#     - Hỗ trợ chẩn đoán khối u lành, ác tính dựa trên ảnh chụp y tế.
#     - Dự đoán sản phẩm kinh tế như giá nhà, giá đất.
#     - Phân loại, dự đoán tin nhắn, email là spam/không spam.
#     - Phiên dịch, dịch thuật
#     ...

# %% [markdown]
# * Mặt khác, nó là nền tảng cho sự vận hành của nhiều ứng dụng máy tính hay thuật toán giải quyết nhiều bài toán khó, là một phần không thể thiết của lĩnh vực khoa học máy tính nói riêng và cả nền công nghiệp khoa học-kỹ thuật nói chung.
#     - Thuật toán chuyển đổi chữ viết tay thành ký tự máy.
#     - Bài toán dịch thuật.
#     - Mô hình ngôn ngữ lớn (Large Language Models - LLMs) - giao tiếp như con người.
#     - Trí tuệ nhân tạo tổng quát - Artificial General Intelligent (AGI)
#     - Retrieval-Augmented Generation (RAG)
#     ...
